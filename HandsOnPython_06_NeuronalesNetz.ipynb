# %% [markdown]
# Dieses Notebook zeigt, wie man ein spezielles Rekurrentes Neuronales Netz (LSTM) zur Vorhersage von Energieverbrauchsdaten trainieren kann.
# Hierfür werden die Bibliotheken keras, sowie sci-kit learn verwendet.
# Das Notebook orientiert sich an folgendem Tutorial: https://www.elab2go.de/demo-py5/ (Autoren: Prof. Dr. Eva Maria Kiss, B. Sc. Franc Willy Pouhela, M. Sc. Anke Welz)

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import math

# matplotlib und seaborn zum Plotten
import matplotlib.pyplot as plt
import seaborn as sns

# scikit-learn für Überwachtes Lernen
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import max_error

# keras für Neuronale Netze
import tensorflow as tf 
import keras as keras
from keras.models import Sequential 
from keras.layers import Dense, LSTM, Dropout 
from keras.utils.vis_utils import plot_model 
from keras import activations

# Für das Darstellen von Bildern im SVG-Format
import graphviz as gv
import pydot
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG

# %%
# Daten einlesen
data = pd.read_csv('opsd_2016-2019.csv')

# %%
data.head()
# Out:
#         Datum  Verbrauch    Wind  Solar  Wind+Solar
# 0  2016-01-01    1007.11  107.21  18.56      125.77
# 1  2016-01-02    1147.89  409.62   9.40      419.02
# 2  2016-01-03    1130.63  406.30  13.52      419.82
# 3  2016-01-04    1385.93  278.46  10.08      288.54
# 4  2016-01-05    1430.11  206.47  12.55      219.02

# %%
data.tail()
# Out:
#            Datum  Verbrauch    Wind  Solar  Wind+Solar
# 1456  2019-12-27    1172.20  146.59  20.96      167.55
# 1457  2019-12-28    1141.33  159.13  36.24      195.36
# 1458  2019-12-29    1087.07  349.84  54.91      404.75
# 1459  2019-12-30    1200.05  669.27  53.22      722.49
# 1460  2019-12-31    1124.93  425.22  36.56      461.79

# %% [markdown]
# # Aufgabe 1: Datenvorbereitung
#
#
# * a) Überprüfen Sie, ob in dem Datensatz NaN enthalten sind. Falls ja, überlegen Sie sich, wie Sie damit am besten umgehen.
# *   b) Ist es sinnvoll, mit allen Merkmalen fortzufahren? Was müssen Sie tun um diese Frage beantworten zu können?
# *   c) Bringen Sie die Spalte "Datum" in ein geeignetes Format und indizieren Sie das dataframe mit dieser Spalte

# %%
# Frage 1 a) Überprüfen auf NaN

data.isna().sum()
# Out:
# Datum         0
# Verbrauch     0
# Wind          0
# Solar         0
# Wind+Solar    0
# dtype: int64

# %%
# Frage 1 b)

# .....
# nein. Weil es da ziemlich eine Proportion zwischen die Merkmale "Wind" und "Wind + Solar" gibt
import seaborn as sns
sns.heatmap(data.corr(), annot=True, fmt='.2f', vmin=-1, vmax=1)
# Out:
# C:\Users\haypsilcn\AppData\Local\Temp\ipykernel_10952\1856890059.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, fmt='.2f', vmin=-1, vmax=1)
# <AxesSubplot: >

# %%
# ...

# %%
# Frage 1 c)
data['Datum'] = pd.to_datetime(data['Datum'])
data.set_index('Datum', inplace=True)
data.head()
# Out:
#             Verbrauch    Wind  Solar  Wind+Solar
# Datum
# 2016-01-01    1007.11  107.21  18.56      125.77
# 2016-01-02    1147.89  409.62   9.40      419.02
# 2016-01-03    1130.63  406.30  13.52      419.82
# 2016-01-04    1385.93  278.46  10.08      288.54
# 2016-01-05    1430.11  206.47  12.55      219.02

# %%
# Plotten des Stromverbrauchs. Der Stromverbrauch soll später mithilfe des Neuronalen Netzes vorhergesagt werden.

sns.set(rc={'figure.figsize':(12, 4)})
sns.set_color_codes('bright')

ax = data['Verbrauch'].plot(linewidth=1, color='b', marker = '.')
ax.set_title('Täglicher Stromverbrauch')
ax.set_xlabel('Datum');
ax.set_ylabel('GwH');

# %% [markdown]
# # Aufgabe 2
#
# Im nächsten Codeblock werden zeitlich versetzte Merkmale (sogenannte Lagged Features) erzeugt.
#
# *   a) Was macht dabei die Funktion shift()? Schauen Sie in der pandas Dokumentation nach!
# *   b) Was macht die Funktion concat()? Schauen Sie auch das in der pandas Dokumentation nach!
# *   c) Führen Sie die untenstehende Zelle aus und Lassen Sie sich anschließend die ersten 10 Zeilen des neu erzeugten dataframes ausgeben. Hat das Erzeugen der zeitlich versetzten Merkmale erfolgreich funktioniert?

# %% [markdown]
# # Antworten
#
#
#
# *   a) die Funktion shift() wird verwendet, um die Position der Spalte oder Zeile um einen gewissen Wert zu verschieben.
# *   b) concat() wird verwendet, um das Pandas-Objekt in eine DataFrame zu verketten
# *   c) damit man die Wochentage vergleichen kann

# %%
# Erzeuge zeitlich versetzte Merkmale (lagged features)

consumption = pd.DataFrame(data['Verbrauch'])

data = pd.concat([consumption.shift(7),consumption.shift(6), consumption.shift(5), consumption.shift(4), 
                  consumption.shift(3), consumption.shift(2), consumption.shift(1), data[['Verbrauch']]], axis=1)

data.columns =  ['t-7', 't-6', 't-5', 't-4', 't-3', 't-2', 't-1', 'Verbrauch']

data.head()

data.dropna(inplace=True)

# %%
data.head(10)
# Out:
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2016-01-08  1007.11  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61
# 2016-01-09  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35
# 2016-01-10  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50
# 2016-01-11  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10
# 2016-01-12  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10  1493.80
# 2016-01-13  1375.73  1480.61  1469.35  1236.50  1133.10  1493.80  1517.06
# 2016-01-14  1480.61  1469.35  1236.50  1133.10  1493.80  1517.06  1525.13
# 2016-01-15  1469.35  1236.50  1133.10  1493.80  1517.06  1525.13  1518.12
# 2016-01-16  1236.50  1133.10  1493.80  1517.06  1525.13  1518.12  1515.73
# 2016-01-17  1133.10  1493.80  1517.06  1525.13  1518.12  1515.73  1287.07
#
#             Verbrauch
# Datum
# 2016-01-08    1469.35
# 2016-01-09    1236.50
# 2016-01-10    1133.10
# 2016-01-11    1493.80
# 2016-01-12    1517.06
# 2016-01-13    1525.13
# 2016-01-14    1518.12
# 2016-01-15    1515.73
# 2016-01-16    1287.07
# 2016-01-17    1208.63

# %%
# Daten in Trainings- und Testset aufspalten

TEST_SPLIT = 0.1 
#data = data.drop(columns = ['Wind', 'Solar'])
train_size = int(len(data) * (1- TEST_SPLIT))
test_size = len(data) - train_size
train = data.iloc[0:train_size]
test = data.iloc[train_size:len(data)]
print("Trainingsdaten:") 
print(train.head())
print(train.tail())

print("Testdaten:") 
print(test.head())
print(test.tail())
# Out:
# Trainingsdaten:
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2016-01-08  1007.11  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61
# 2016-01-09  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35
# 2016-01-10  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50
# 2016-01-11  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10
# 2016-01-12  1430.11  1375.73  1480.61  1469.35  1236.50  1133.10  1493.80
#
#             Verbrauch
# Datum
# 2016-01-08    1469.35
# 2016-01-09    1236.50
# 2016-01-10    1133.10
# 2016-01-11    1493.80
# 2016-01-12    1517.06
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-08-03  1141.75  1055.72  1337.17  1380.32  1361.27  1330.42  1305.06
# 2019-08-04  1055.72  1337.17  1380.32  1361.27  1330.42  1305.06  1086.43
# 2019-08-05  1337.17  1380.32  1361.27  1330.42  1305.06  1086.43  1001.21
# 2019-08-06  1380.32  1361.27  1330.42  1305.06  1086.43  1001.21  1278.04
# 2019-08-07  1361.27  1330.42  1305.06  1086.43  1001.21  1278.04  1315.79
#
#             Verbrauch
# Datum
# 2019-08-03    1086.43
# 2019-08-04    1001.21
# 2019-08-05    1278.04
# 2019-08-06    1315.79
# 2019-08-07    1324.10
# Testdaten:
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-08-08  1330.42  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10
# 2019-08-09  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62
# 2019-08-10  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62  1318.76
# 2019-08-11  1001.21  1278.04  1315.79  1324.10  1326.62  1318.76  1132.40
# 2019-08-12  1278.04  1315.79  1324.10  1326.62  1318.76  1132.40  1043.49
#
#             Verbrauch
# Datum
# 2019-08-08    1326.62
# 2019-08-09    1318.76
# 2019-08-10    1132.40
# 2019-08-11    1043.49
# 2019-08-12    1299.03
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-12-27  1354.26  1206.42  1140.68  1214.86  1112.49  1042.24  1042.69
# 2019-12-28  1206.42  1140.68  1214.86  1112.49  1042.24  1042.69  1172.20
# 2019-12-29  1140.68  1214.86  1112.49  1042.24  1042.69  1172.20  1141.33
# 2019-12-30  1214.86  1112.49  1042.24  1042.69  1172.20  1141.33  1087.07
# 2019-12-31  1112.49  1042.24  1042.69  1172.20  1141.33  1087.07  1200.05
#
#             Verbrauch
# Datum
# 2019-12-27    1172.20
# 2019-12-28    1141.33
# 2019-12-29    1087.07
# 2019-12-30    1200.05
# 2019-12-31    1124.93

# %%
# Daten auf den Wertebereich [0, 1] skalieren

scaler = MinMaxScaler(feature_range = (0,1))

train_s = scaler.fit_transform(np.array(train))
test_s = scaler.fit_transform(np.array(test))

print("Trainingsdaten (unskaliert)\n")
print(train.head(3))
print("\nTrainingsdaten (skaliert)\n")
train_s = pd.DataFrame( train_s , columns = data.columns)
train_s = train_s.set_index(train.index )
print(train_s.head(3))

print("Testdaten (unskaliert)\n")
print(test.head(3))
print("\nTestdaten (skaliert)\n")
test_s = pd.DataFrame( test_s , columns = data.columns)
test_s = test_s.set_index(test.index )
print(test_s.head(3))
# Out:
# Trainingsdaten (unskaliert)
#
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2016-01-08  1007.11  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61
# 2016-01-09  1147.89  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35
# 2016-01-10  1130.63  1385.93  1430.11  1375.73  1480.61  1469.35  1236.50
#
#             Verbrauch
# Datum
# 2016-01-08    1469.35
# 2016-01-09    1236.50
# 2016-01-10    1133.10
#
# Trainingsdaten (skaliert)
#
#                  t-7       t-6       t-5       t-4       t-3       t-2  \
# Datum
# 2016-01-08  0.102986  0.303656  0.279054  0.642962  0.705937  0.628423
# 2016-01-09  0.303656  0.279054  0.642962  0.705937  0.628423  0.777920
# 2016-01-10  0.279054  0.642962  0.705937  0.628423  0.777920  0.761870
#
#                  t-1  Verbrauch
# Datum
# 2016-01-08  0.777920   0.761870
# 2016-01-09  0.761870   0.429962
# 2016-01-10  0.429962   0.282574
# Testdaten (unskaliert)
#
#                 t-7      t-6      t-5      t-4      t-3      t-2      t-1  \
# Datum
# 2019-08-08  1330.42  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10
# 2019-08-09  1305.06  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62
# 2019-08-10  1086.43  1001.21  1278.04  1315.79  1324.10  1326.62  1318.76
#
#             Verbrauch
# Datum
# 2019-08-08    1326.62
# 2019-08-09    1318.76
# 2019-08-10    1132.40
#
# Testdaten (skaliert)
#
#                  t-7       t-6       t-5       t-4       t-3       t-2  \
# Datum
# 2019-08-08  0.560969  0.517756  0.145214  0.000000  0.449950  0.516926
# 2019-08-09  0.517756  0.145214  0.000000  0.471714  0.516926  0.531669
# 2019-08-10  0.145214  0.000000  0.471714  0.536039  0.531669  0.536140
#
#                  t-1  Verbrauch
# Datum
# 2019-08-08  0.531669   0.536140
# 2019-08-09  0.536140   0.522195
# 2019-08-10  0.522195   0.191558

# %%
# In Merkmale und Label aufteilen

X_train = train_s.drop(columns = ['Verbrauch'])
y_train = pd.DataFrame(train_s['Verbrauch'])

print(X_train.head())
print(y_train.head())
# Out:
#                  t-7       t-6       t-5       t-4       t-3       t-2  \
# Datum
# 2016-01-08  0.102986  0.303656  0.279054  0.642962  0.705937  0.628423
# 2016-01-09  0.303656  0.279054  0.642962  0.705937  0.628423  0.777920
# 2016-01-10  0.279054  0.642962  0.705937  0.628423  0.777920  0.761870
# 2016-01-11  0.642962  0.705937  0.628423  0.777920  0.761870  0.429962
# 2016-01-12  0.705937  0.628423  0.777920  0.761870  0.429962  0.282574
#
#                  t-1
# Datum
# 2016-01-08  0.777920
# 2016-01-09  0.761870
# 2016-01-10  0.429962
# 2016-01-11  0.282574
# 2016-01-12  0.796722
#             Verbrauch
# Datum
# 2016-01-08   0.761870
# 2016-01-09   0.429962
# 2016-01-10   0.282574
# 2016-01-11   0.796722
# 2016-01-12   0.829877

# %%
TIMESTEPS = 7 # Länge eines gleitenden Zeitfensters
UNITS = 10 # Ausgabedimension einer einzelnen LSTM-Schicht
N_LAYER = 2 # Anzahl an LSTM-Schichten

# Initialisiere ein sequentielles Modell (Modell mit mehreren Schichten)
model = Sequential(name='sequential') 

#Füge so viele Schichten hinzu, wie in N_LAYER angegeben
for i in range(N_LAYER):

  lstm_layer = LSTM(units = UNITS, # Dimension der Ausgabe
                    input_shape=(TIMESTEPS,1), # Dimension der Eingabe (1. Dimension entspricht Anzahl Zeitschritte, 2. Dimension:  1, da nur ein Merkmal = Verbrauch über die Zeit betrachtet wird (univariates Problem) )
                    return_sequences=True, # wir wollen die gesamte Ausgabesequenz der jeweiligen LSTM-Schicht in die nächste LSTM-Schicht weitergeben können
                    name = 'lstm_' + str(i+1)) # Schichten werden mit "lstm_" + Schichtnummer benannt
                   
  model.add(lstm_layer) # Schicht dem Modell hinzufügen


# weitere LSTM Schicht hinzufügen, bei der nur die letzte Ausgabe (und nicht wie oben die ganze Sequenz) in die nächste Schicht weitergegeben wird
model.add(LSTM(units = UNITS, input_shape=(TIMESTEPS,1), name = 'lstm_' + str(N_LAYER+1)))

# Lineares Layer mit ReLU-Aktivierungsfunktion
model.add(Dense(units = 1, name='dense_1'))#, activation=activations.tanh))

# Konfiguriere das Modell für die Trainingsphase 

# Angeben welcher Optimierer verwendet werden soll
opt = tf.keras.optimizers.Adam(learning_rate=0.01)

# über welche Verlustfunktion optimiert werden soll 
# und wie die Performance des Modells gemessen werden soll (hier werden Verlustfunktion und Performancemetrik gleich gewählt, muss aber nicht so sein))
model.compile(optimizer = opt, loss = "mse", metrics=['mean_squared_error'])

# Zusammenfassung und Visualisierung des Modells
model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 7, 10)             480
#
#  lstm_2 (LSTM)               (None, 7, 10)             840
#
#  lstm_3 (LSTM)               (None, 10)                840
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 2,171
# Trainable params: 2,171
# Non-trainable params: 0
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Aufgabe 3
#
# Welchen Parameter der obigen Codezelle müssten Sie verändern, um 3 LSTM Schichten zu bekommen?

# %% [markdown]
# # Aufgabe 4
#
# Das Neuronale Netz wird in der unten stehenden Codezelle trainiert. Führen Sie den Code aus.
# Nach wie vielen Epochen wird das Training auf jeden Fall stoppen?

# %%
# Modell trainieren

# Erstelle Callback für Stop-Kriterium
from keras.callbacks import EarlyStopping, CSVLogger
cb_stop = EarlyStopping(monitor='val_loss', mode='min', 
                        verbose=1, patience=200)
log_file = 'demo-py5-log.csv'
cb_logger = CSVLogger(log_file, append=False, separator=';')

# X_train erhält eine zusätzliche Dimension und wird dreidimensional
X_train = np.array(X_train)
X_train = np.reshape(X_train, 
                     (X_train.shape[0], X_train.shape[1], 1))

print(X_train.shape)

# Trainiere das Modell mit Hilfe der Funktion fit()
BATCH_SIZE = 64
EPOCHS = 1000
history = model.fit(X_train, y_train, 
                    epochs=EPOCHS, batch_size=BATCH_SIZE, 
                    validation_split=TEST_SPLIT, verbose=2, 
                    callbacks=[cb_logger, cb_stop])

# Speichere das Modell im Format HDF5
model.save("model_adam.h5")

print("History");print(history.history.keys());
# Out:
# (1308, 7, 1)
# Epoch 1/1000
# 19/19 - 5s - loss: 0.1126 - mean_squared_error: 0.1126 - val_loss: 0.0424 - val_mean_squared_error: 0.0424 - 5s/epoch - 278ms/step
# Epoch 2/1000
# 19/19 - 0s - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0426 - val_mean_squared_error: 0.0426 - 124ms/epoch - 7ms/step
# Epoch 3/1000
# 19/19 - 0s - loss: 0.0454 - mean_squared_error: 0.0454 - val_loss: 0.0445 - val_mean_squared_error: 0.0445 - 128ms/epoch - 7ms/step
# Epoch 4/1000
# 19/19 - 0s - loss: 0.0422 - mean_squared_error: 0.0422 - val_loss: 0.0462 - val_mean_squared_error: 0.0462 - 131ms/epoch - 7ms/step
# Epoch 5/1000
# 19/19 - 0s - loss: 0.0374 - mean_squared_error: 0.0374 - val_loss: 0.0404 - val_mean_squared_error: 0.0404 - 125ms/epoch - 7ms/step
# Epoch 6/1000
# 19/19 - 0s - loss: 0.0334 - mean_squared_error: 0.0334 - val_loss: 0.0383 - val_mean_squared_error: 0.0383 - 126ms/epoch - 7ms/step
# Epoch 7/1000
# 19/19 - 0s - loss: 0.0311 - mean_squared_error: 0.0311 - val_loss: 0.0343 - val_mean_squared_error: 0.0343 - 122ms/epoch - 6ms/step
# Epoch 8/1000
# 19/19 - 0s - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0297 - val_mean_squared_error: 0.0297 - 120ms/epoch - 6ms/step
# Epoch 9/1000
# 19/19 - 0s - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0289 - val_mean_squared_error: 0.0289 - 121ms/epoch - 6ms/step
# Epoch 10/1000
# 19/19 - 0s - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0284 - val_mean_squared_error: 0.0284 - 121ms/epoch - 6ms/step
# Epoch 11/1000
# 19/19 - 0s - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - 121ms/epoch - 6ms/step
# Epoch 12/1000
# 19/19 - 0s - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0243 - val_mean_squared_error: 0.0243 - 122ms/epoch - 6ms/step
# Epoch 13/1000
# 19/19 - 0s - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - 122ms/epoch - 6ms/step
# Epoch 14/1000
# 19/19 - 0s - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - 130ms/epoch - 7ms/step
# Epoch 15/1000
# 19/19 - 0s - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - 120ms/epoch - 6ms/step
# Epoch 16/1000
# 19/19 - 0s - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - 121ms/epoch - 6ms/step
# Epoch 17/1000
# 19/19 - 0s - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0251 - val_mean_squared_error: 0.0251 - 129ms/epoch - 7ms/step
# Epoch 18/1000
# 19/19 - 0s - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0254 - val_mean_squared_error: 0.0254 - 121ms/epoch - 6ms/step
# Epoch 19/1000
# 19/19 - 0s - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - 121ms/epoch - 6ms/step
# Epoch 20/1000
# 19/19 - 0s - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - 121ms/epoch - 6ms/step
# Epoch 21/1000
# 19/19 - 0s - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0280 - val_mean_squared_error: 0.0280 - 130ms/epoch - 7ms/step
# Epoch 22/1000
# 19/19 - 0s - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - 133ms/epoch - 7ms/step
# Epoch 23/1000
# 19/19 - 0s - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 120ms/epoch - 6ms/step
# Epoch 24/1000
# 19/19 - 0s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - 121ms/epoch - 6ms/step
# Epoch 25/1000
# 19/19 - 0s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - 131ms/epoch - 7ms/step
# Epoch 26/1000
# 19/19 - 0s - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - 123ms/epoch - 6ms/step
# Epoch 27/1000
# 19/19 - 0s - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0185 - val_mean_squared_error: 0.0185 - 121ms/epoch - 6ms/step
# Epoch 28/1000
# 19/19 - 0s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0173 - val_mean_squared_error: 0.0173 - 125ms/epoch - 7ms/step
# Epoch 29/1000
# 19/19 - 0s - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - 122ms/epoch - 6ms/step
# Epoch 30/1000
# 19/19 - 0s - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0183 - val_mean_squared_error: 0.0183 - 122ms/epoch - 6ms/step
# Epoch 31/1000
# 19/19 - 0s - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - 120ms/epoch - 6ms/step
# Epoch 32/1000
# 19/19 - 0s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0163 - val_mean_squared_error: 0.0163 - 121ms/epoch - 6ms/step
# Epoch 33/1000
# 19/19 - 0s - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0165 - val_mean_squared_error: 0.0165 - 123ms/epoch - 6ms/step
# Epoch 34/1000
# 19/19 - 0s - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - 123ms/epoch - 6ms/step
# Epoch 35/1000
# 19/19 - 0s - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - 123ms/epoch - 6ms/step
# Epoch 36/1000
# 19/19 - 0s - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0175 - val_mean_squared_error: 0.0175 - 127ms/epoch - 7ms/step
# Epoch 37/1000
# 19/19 - 0s - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0167 - val_mean_squared_error: 0.0167 - 122ms/epoch - 6ms/step
# Epoch 38/1000
# 19/19 - 0s - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - 121ms/epoch - 6ms/step
# Epoch 39/1000
# 19/19 - 0s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0162 - val_mean_squared_error: 0.0162 - 120ms/epoch - 6ms/step
# Epoch 40/1000
# 19/19 - 0s - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0164 - val_mean_squared_error: 0.0164 - 121ms/epoch - 6ms/step
# Epoch 41/1000
# 19/19 - 0s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0168 - val_mean_squared_error: 0.0168 - 122ms/epoch - 6ms/step
# Epoch 42/1000
# 19/19 - 0s - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0166 - val_mean_squared_error: 0.0166 - 122ms/epoch - 6ms/step
# Epoch 43/1000
# 19/19 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0158 - val_mean_squared_error: 0.0158 - 121ms/epoch - 6ms/step
# Epoch 44/1000
# 19/19 - 0s - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0157 - val_mean_squared_error: 0.0157 - 121ms/epoch - 6ms/step
# Epoch 45/1000
# 19/19 - 0s - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - 121ms/epoch - 6ms/step
# Epoch 46/1000
# 19/19 - 0s - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 122ms/epoch - 6ms/step
# Epoch 47/1000
# 19/19 - 0s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 125ms/epoch - 7ms/step
# Epoch 48/1000
# 19/19 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 120ms/epoch - 6ms/step
# Epoch 49/1000
# 19/19 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - 120ms/epoch - 6ms/step
# Epoch 50/1000
# 19/19 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - 122ms/epoch - 6ms/step
# Epoch 51/1000
# 19/19 - 0s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 119ms/epoch - 6ms/step
# Epoch 52/1000
# 19/19 - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0143 - val_mean_squared_error: 0.0143 - 120ms/epoch - 6ms/step
# Epoch 53/1000
# 19/19 - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 121ms/epoch - 6ms/step
# Epoch 54/1000
# 19/19 - 0s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 123ms/epoch - 6ms/step
# Epoch 55/1000
# 19/19 - 0s - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 120ms/epoch - 6ms/step
# Epoch 56/1000
# 19/19 - 0s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 121ms/epoch - 6ms/step
# Epoch 57/1000
# 19/19 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - 120ms/epoch - 6ms/step
# Epoch 58/1000
# 19/19 - 0s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 126ms/epoch - 7ms/step
# Epoch 59/1000
# 19/19 - 0s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 121ms/epoch - 6ms/step
# Epoch 60/1000
# 19/19 - 0s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 121ms/epoch - 6ms/step
# Epoch 61/1000
# 19/19 - 0s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 120ms/epoch - 6ms/step
# Epoch 62/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - 128ms/epoch - 7ms/step
# Epoch 63/1000
# 19/19 - 0s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 120ms/epoch - 6ms/step
# Epoch 64/1000
# 19/19 - 0s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 120ms/epoch - 6ms/step
# Epoch 65/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 120ms/epoch - 6ms/step
# Epoch 66/1000
# 19/19 - 0s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 124ms/epoch - 7ms/step
# Epoch 67/1000
# 19/19 - 0s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 120ms/epoch - 6ms/step
# Epoch 68/1000
# 19/19 - 0s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 120ms/epoch - 6ms/step
# Epoch 69/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 120ms/epoch - 6ms/step
# Epoch 70/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 125ms/epoch - 7ms/step
# Epoch 71/1000
# 19/19 - 0s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 121ms/epoch - 6ms/step
# Epoch 72/1000
# 19/19 - 0s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 121ms/epoch - 6ms/step
# Epoch 73/1000
# 19/19 - 0s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 120ms/epoch - 6ms/step
# Epoch 74/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 123ms/epoch - 6ms/step
# Epoch 75/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 120ms/epoch - 6ms/step
# Epoch 76/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 121ms/epoch - 6ms/step
# Epoch 77/1000
# 19/19 - 0s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 120ms/epoch - 6ms/step
# Epoch 78/1000
# 19/19 - 0s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 121ms/epoch - 6ms/step
# Epoch 79/1000
# 19/19 - 0s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 119ms/epoch - 6ms/step
# Epoch 80/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - 120ms/epoch - 6ms/step
# Epoch 81/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 120ms/epoch - 6ms/step
# Epoch 82/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 120ms/epoch - 6ms/step
# Epoch 83/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 121ms/epoch - 6ms/step
# Epoch 84/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 120ms/epoch - 6ms/step
# Epoch 85/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 121ms/epoch - 6ms/step
# Epoch 86/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 121ms/epoch - 6ms/step
# Epoch 87/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 142ms/epoch - 7ms/step
# Epoch 88/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 121ms/epoch - 6ms/step
# Epoch 89/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 119ms/epoch - 6ms/step
# Epoch 90/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 119ms/epoch - 6ms/step
# Epoch 91/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 123ms/epoch - 6ms/step
# Epoch 92/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 120ms/epoch - 6ms/step
# Epoch 93/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 121ms/epoch - 6ms/step
# Epoch 94/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 120ms/epoch - 6ms/step
# Epoch 95/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 125ms/epoch - 7ms/step
# Epoch 96/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 120ms/epoch - 6ms/step
# Epoch 97/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 120ms/epoch - 6ms/step
# Epoch 98/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 119ms/epoch - 6ms/step
# Epoch 99/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 124ms/epoch - 7ms/step
# Epoch 100/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 120ms/epoch - 6ms/step
# Epoch 101/1000
# 19/19 - 0s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - 122ms/epoch - 6ms/step
# Epoch 102/1000
# 19/19 - 0s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 120ms/epoch - 6ms/step
# Epoch 103/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 123ms/epoch - 6ms/step
# Epoch 104/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - 120ms/epoch - 6ms/step
# Epoch 105/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 120ms/epoch - 6ms/step
# Epoch 106/1000
# 19/19 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - 120ms/epoch - 6ms/step
# Epoch 107/1000
# 19/19 - 0s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 123ms/epoch - 6ms/step
# Epoch 108/1000
# 19/19 - 0s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 120ms/epoch - 6ms/step
# Epoch 109/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 122ms/epoch - 6ms/step
# Epoch 110/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 120ms/epoch - 6ms/step
# Epoch 111/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 122ms/epoch - 6ms/step
# Epoch 112/1000
# 19/19 - 0s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 120ms/epoch - 6ms/step
# Epoch 113/1000
# 19/19 - 0s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 120ms/epoch - 6ms/step
# Epoch 114/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 121ms/epoch - 6ms/step
# Epoch 115/1000
# 19/19 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - 140ms/epoch - 7ms/step
# Epoch 116/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 125ms/epoch - 7ms/step
# Epoch 117/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 126ms/epoch - 7ms/step
# Epoch 118/1000
# 19/19 - 0s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 123ms/epoch - 6ms/step
# Epoch 119/1000
# 19/19 - 0s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 121ms/epoch - 6ms/step
# Epoch 120/1000
# 19/19 - 0s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 120ms/epoch - 6ms/step
# Epoch 121/1000
# 19/19 - 0s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 121ms/epoch - 6ms/step
# Epoch 122/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 122ms/epoch - 6ms/step
# Epoch 123/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 124ms/epoch - 7ms/step
# Epoch 124/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - 125ms/epoch - 7ms/step
# Epoch 125/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 123ms/epoch - 6ms/step
# Epoch 126/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 121ms/epoch - 6ms/step
# Epoch 127/1000
# 19/19 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 121ms/epoch - 6ms/step
# Epoch 128/1000
# 19/19 - 0s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 127ms/epoch - 7ms/step
# Epoch 129/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 122ms/epoch - 6ms/step
# Epoch 130/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - 120ms/epoch - 6ms/step
# Epoch 131/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 124ms/epoch - 7ms/step
# Epoch 132/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 122ms/epoch - 6ms/step
# Epoch 133/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 122ms/epoch - 6ms/step
# Epoch 134/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 120ms/epoch - 6ms/step
# Epoch 135/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 122ms/epoch - 6ms/step
# Epoch 136/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 123ms/epoch - 6ms/step
# Epoch 137/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 119ms/epoch - 6ms/step
# Epoch 138/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 120ms/epoch - 6ms/step
# Epoch 139/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 122ms/epoch - 6ms/step
# Epoch 140/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 121ms/epoch - 6ms/step
# Epoch 141/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 121ms/epoch - 6ms/step
# Epoch 142/1000
# 19/19 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 119ms/epoch - 6ms/step
# Epoch 143/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 122ms/epoch - 6ms/step
# Epoch 144/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 121ms/epoch - 6ms/step
# Epoch 145/1000
# 19/19 - 0s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 125ms/epoch - 7ms/step
# Epoch 146/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 121ms/epoch - 6ms/step
# Epoch 147/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 121ms/epoch - 6ms/step
# Epoch 148/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 119ms/epoch - 6ms/step
# Epoch 149/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 122ms/epoch - 6ms/step
# Epoch 150/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 121ms/epoch - 6ms/step
# Epoch 151/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 121ms/epoch - 6ms/step
# Epoch 152/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 121ms/epoch - 6ms/step
# Epoch 153/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 129ms/epoch - 7ms/step
# Epoch 154/1000
# 19/19 - 0s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 127ms/epoch - 7ms/step
# Epoch 155/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 121ms/epoch - 6ms/step
# Epoch 156/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 120ms/epoch - 6ms/step
# Epoch 157/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 123ms/epoch - 6ms/step
# Epoch 158/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 126ms/epoch - 7ms/step
# Epoch 159/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 121ms/epoch - 6ms/step
# Epoch 160/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 119ms/epoch - 6ms/step
# Epoch 161/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 118ms/epoch - 6ms/step
# Epoch 162/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 121ms/epoch - 6ms/step
# Epoch 163/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 122ms/epoch - 6ms/step
# Epoch 164/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 120ms/epoch - 6ms/step
# Epoch 165/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 119ms/epoch - 6ms/step
# Epoch 166/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 122ms/epoch - 6ms/step
# Epoch 167/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 122ms/epoch - 6ms/step
# Epoch 168/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 123ms/epoch - 6ms/step
# Epoch 169/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 120ms/epoch - 6ms/step
# Epoch 170/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 123ms/epoch - 6ms/step
# Epoch 171/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 121ms/epoch - 6ms/step
# Epoch 172/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 121ms/epoch - 6ms/step
# Epoch 173/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 120ms/epoch - 6ms/step
# Epoch 174/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 123ms/epoch - 6ms/step
# Epoch 175/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 120ms/epoch - 6ms/step
# Epoch 176/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 121ms/epoch - 6ms/step
# Epoch 177/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 120ms/epoch - 6ms/step
# Epoch 178/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 121ms/epoch - 6ms/step
# Epoch 179/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 120ms/epoch - 6ms/step
# Epoch 180/1000
# 19/19 - 0s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 122ms/epoch - 6ms/step
# Epoch 181/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 119ms/epoch - 6ms/step
# Epoch 182/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 122ms/epoch - 6ms/step
# Epoch 183/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 121ms/epoch - 6ms/step
# Epoch 184/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 124ms/epoch - 7ms/step
# Epoch 185/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 120ms/epoch - 6ms/step
# Epoch 186/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 122ms/epoch - 6ms/step
# Epoch 187/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 125ms/epoch - 7ms/step
# Epoch 188/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 124ms/epoch - 7ms/step
# Epoch 189/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 121ms/epoch - 6ms/step
# Epoch 190/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 122ms/epoch - 6ms/step
# Epoch 191/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 123ms/epoch - 6ms/step
# Epoch 192/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 193/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 120ms/epoch - 6ms/step
# Epoch 194/1000
# 19/19 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 120ms/epoch - 6ms/step
# Epoch 195/1000
# 19/19 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 124ms/epoch - 7ms/step
# Epoch 196/1000
# 19/19 - 0s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 122ms/epoch - 6ms/step
# Epoch 197/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 120ms/epoch - 6ms/step
# Epoch 198/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 121ms/epoch - 6ms/step
# Epoch 199/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 123ms/epoch - 6ms/step
# Epoch 200/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 122ms/epoch - 6ms/step
# Epoch 201/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 123ms/epoch - 6ms/step
# Epoch 202/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 121ms/epoch - 6ms/step
# Epoch 203/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 122ms/epoch - 6ms/step
# Epoch 204/1000
# 19/19 - 0s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 124ms/epoch - 7ms/step
# Epoch 205/1000
# 19/19 - 0s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 123ms/epoch - 6ms/step
# Epoch 206/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 207/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 121ms/epoch - 6ms/step
# Epoch 208/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 209/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 120ms/epoch - 6ms/step
# Epoch 210/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 128ms/epoch - 7ms/step
# Epoch 211/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 121ms/epoch - 6ms/step
# Epoch 212/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 122ms/epoch - 6ms/step
# Epoch 213/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 122ms/epoch - 6ms/step
# Epoch 214/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 121ms/epoch - 6ms/step
# Epoch 215/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 121ms/epoch - 6ms/step
# Epoch 216/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 122ms/epoch - 6ms/step
# Epoch 217/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 120ms/epoch - 6ms/step
# Epoch 218/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 122ms/epoch - 6ms/step
# Epoch 219/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 121ms/epoch - 6ms/step
# Epoch 220/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 122ms/epoch - 6ms/step
# Epoch 221/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 121ms/epoch - 6ms/step
# Epoch 222/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 121ms/epoch - 6ms/step
# Epoch 223/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 121ms/epoch - 6ms/step
# Epoch 224/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 122ms/epoch - 6ms/step
# Epoch 225/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 123ms/epoch - 6ms/step
# Epoch 226/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 119ms/epoch - 6ms/step
# Epoch 227/1000
# 19/19 - 0s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 121ms/epoch - 6ms/step
# Epoch 228/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 124ms/epoch - 7ms/step
# Epoch 229/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 121ms/epoch - 6ms/step
# Epoch 230/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 123ms/epoch - 6ms/step
# Epoch 231/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 121ms/epoch - 6ms/step
# Epoch 232/1000
# 19/19 - 0s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 233/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 122ms/epoch - 6ms/step
# Epoch 234/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 129ms/epoch - 7ms/step
# Epoch 235/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 141ms/epoch - 7ms/step
# Epoch 236/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 150ms/epoch - 8ms/step
# Epoch 237/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 141ms/epoch - 7ms/step
# Epoch 238/1000
# 19/19 - 0s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - 137ms/epoch - 7ms/step
# Epoch 239/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 120ms/epoch - 6ms/step
# Epoch 240/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 122ms/epoch - 6ms/step
# Epoch 241/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 120ms/epoch - 6ms/step
# Epoch 242/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 120ms/epoch - 6ms/step
# Epoch 243/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 120ms/epoch - 6ms/step
# Epoch 244/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 122ms/epoch - 6ms/step
# Epoch 245/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 118ms/epoch - 6ms/step
# Epoch 246/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0077 - val_mean_squared_error: 0.0077 - 120ms/epoch - 6ms/step
# Epoch 247/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 125ms/epoch - 7ms/step
# Epoch 248/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 126ms/epoch - 7ms/step
# Epoch 249/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 121ms/epoch - 6ms/step
# Epoch 250/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 122ms/epoch - 6ms/step
# Epoch 251/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 120ms/epoch - 6ms/step
# Epoch 252/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 123ms/epoch - 6ms/step
# Epoch 253/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 121ms/epoch - 6ms/step
# Epoch 254/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 121ms/epoch - 6ms/step
# Epoch 255/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 120ms/epoch - 6ms/step
# Epoch 256/1000
# 19/19 - 0s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 123ms/epoch - 6ms/step
# Epoch 257/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 120ms/epoch - 6ms/step
# Epoch 258/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0077 - val_mean_squared_error: 0.0077 - 119ms/epoch - 6ms/step
# Epoch 259/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 119ms/epoch - 6ms/step
# Epoch 260/1000
# 19/19 - 0s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 123ms/epoch - 6ms/step
# Epoch 261/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 121ms/epoch - 6ms/step
# Epoch 262/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 129ms/epoch - 7ms/step
# Epoch 263/1000
# 19/19 - 0s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 128ms/epoch - 7ms/step
# Epoch 264/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 125ms/epoch - 7ms/step
# Epoch 265/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 121ms/epoch - 6ms/step
# Epoch 266/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 122ms/epoch - 6ms/step
# Epoch 267/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 121ms/epoch - 6ms/step
# Epoch 268/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 124ms/epoch - 7ms/step
# Epoch 269/1000
# 19/19 - 0s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 120ms/epoch - 6ms/step
# Epoch 270/1000
# 19/19 - 0s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 121ms/epoch - 6ms/step
# Epoch 271/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 121ms/epoch - 6ms/step
# Epoch 272/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - 123ms/epoch - 6ms/step
# Epoch 273/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 120ms/epoch - 6ms/step
# Epoch 274/1000
# 19/19 - 0s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 121ms/epoch - 6ms/step
# Epoch 275/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 120ms/epoch - 6ms/step
# Epoch 276/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 121ms/epoch - 6ms/step
# Epoch 277/1000
# 19/19 - 0s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 122ms/epoch - 6ms/step
# Epoch 278/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 120ms/epoch - 6ms/step
# Epoch 279/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 120ms/epoch - 6ms/step
# Epoch 280/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 122ms/epoch - 6ms/step
# Epoch 281/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 128ms/epoch - 7ms/step
# Epoch 282/1000
# 19/19 - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 124ms/epoch - 7ms/step
# Epoch 283/1000
# 19/19 - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 122ms/epoch - 6ms/step
# Epoch 284/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 128ms/epoch - 7ms/step
# Epoch 285/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 132ms/epoch - 7ms/step
# Epoch 286/1000
# 19/19 - 0s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 126ms/epoch - 7ms/step
# Epoch 287/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 131ms/epoch - 7ms/step
# Epoch 288/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 133ms/epoch - 7ms/step
# Epoch 289/1000
# 19/19 - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - 132ms/epoch - 7ms/step
# Epoch 290/1000
# 19/19 - 0s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 128ms/epoch - 7ms/step
# Epoch 291/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 130ms/epoch - 7ms/step
# Epoch 292/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 123ms/epoch - 6ms/step
# Epoch 293/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 121ms/epoch - 6ms/step
# Epoch 294/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 124ms/epoch - 7ms/step
# Epoch 295/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 122ms/epoch - 6ms/step
# Epoch 296/1000
# 19/19 - 0s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 124ms/epoch - 7ms/step
# Epoch 297/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 124ms/epoch - 7ms/step
# Epoch 298/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0077 - val_mean_squared_error: 0.0077 - 122ms/epoch - 6ms/step
# Epoch 299/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 173ms/epoch - 9ms/step
# Epoch 300/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 168ms/epoch - 9ms/step
# Epoch 301/1000
# 19/19 - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 142ms/epoch - 7ms/step
# Epoch 302/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 127ms/epoch - 7ms/step
# Epoch 303/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 144ms/epoch - 8ms/step
# Epoch 304/1000
# 19/19 - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 132ms/epoch - 7ms/step
# Epoch 305/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 131ms/epoch - 7ms/step
# Epoch 306/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 148ms/epoch - 8ms/step
# Epoch 307/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 151ms/epoch - 8ms/step
# Epoch 308/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 136ms/epoch - 7ms/step
# Epoch 309/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 133ms/epoch - 7ms/step
# Epoch 310/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 128ms/epoch - 7ms/step
# Epoch 311/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 129ms/epoch - 7ms/step
# Epoch 312/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 120ms/epoch - 6ms/step
# Epoch 313/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 121ms/epoch - 6ms/step
# Epoch 314/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 133ms/epoch - 7ms/step
# Epoch 315/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 129ms/epoch - 7ms/step
# Epoch 316/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 141ms/epoch - 7ms/step
# Epoch 317/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 132ms/epoch - 7ms/step
# Epoch 318/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 128ms/epoch - 7ms/step
# Epoch 319/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 320/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 130ms/epoch - 7ms/step
# Epoch 321/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 127ms/epoch - 7ms/step
# Epoch 322/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 132ms/epoch - 7ms/step
# Epoch 323/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 128ms/epoch - 7ms/step
# Epoch 324/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0074 - val_mean_squared_error: 0.0074 - 131ms/epoch - 7ms/step
# Epoch 325/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 129ms/epoch - 7ms/step
# Epoch 326/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 128ms/epoch - 7ms/step
# Epoch 327/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 145ms/epoch - 8ms/step
# Epoch 328/1000
# ...
# Epoch 353/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 151ms/epoch - 8ms/step
# Epoch 354/1000
# 19/19 - 0s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 128ms/epoch - 7ms/step
# Epoch 355/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 134ms/epoch - 7ms/step
# Epoch 356/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 129ms/epoch - 7ms/step
# Epoch 357/1000
# 19/19 - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 128ms/epoch - 7ms/step
# Epoch 358/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 126ms/epoch - 7ms/step
# Epoch 359/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 130ms/epoch - 7ms/step
# Epoch 360/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 133ms/epoch - 7ms/step
# Epoch 361/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 155ms/epoch - 8ms/step
# Epoch 362/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 166ms/epoch - 9ms/step
# Epoch 363/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 153ms/epoch - 8ms/step
# Epoch 364/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 138ms/epoch - 7ms/step
# Epoch 365/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 148ms/epoch - 8ms/step
# Epoch 366/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - 143ms/epoch - 8ms/step
# Epoch 367/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 153ms/epoch - 8ms/step
# Epoch 368/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 145ms/epoch - 8ms/step
# Epoch 369/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - 165ms/epoch - 9ms/step
# Epoch 370/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 253ms/epoch - 13ms/step
# Epoch 371/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 230ms/epoch - 12ms/step
# Epoch 372/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 268ms/epoch - 14ms/step
# Epoch 373/1000
# 19/19 - 0s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 247ms/epoch - 13ms/step
# Epoch 374/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 179ms/epoch - 9ms/step
# Epoch 375/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 167ms/epoch - 9ms/step
# Epoch 376/1000
# 19/19 - 0s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 192ms/epoch - 10ms/step
# Epoch 377/1000
# 19/19 - 0s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 153ms/epoch - 8ms/step
# Epoch 378/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 183ms/epoch - 10ms/step
# Epoch 379/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 171ms/epoch - 9ms/step
# Epoch 380/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 166ms/epoch - 9ms/step
# Epoch 381/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 143ms/epoch - 8ms/step
# Epoch 382/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 142ms/epoch - 7ms/step
# Epoch 383/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 122ms/epoch - 6ms/step
# Epoch 384/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 136ms/epoch - 7ms/step
# Epoch 385/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 122ms/epoch - 6ms/step
# Epoch 386/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 122ms/epoch - 6ms/step
# Epoch 387/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 122ms/epoch - 6ms/step
# Epoch 388/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 124ms/epoch - 7ms/step
# Epoch 389/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 121ms/epoch - 6ms/step
# Epoch 390/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 124ms/epoch - 7ms/step
# Epoch 391/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 132ms/epoch - 7ms/step
# Epoch 392/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 132ms/epoch - 7ms/step
# Epoch 393/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 122ms/epoch - 6ms/step
# Epoch 394/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 125ms/epoch - 7ms/step
# Epoch 395/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 123ms/epoch - 6ms/step
# Epoch 396/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 148ms/epoch - 8ms/step
# Epoch 397/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 128ms/epoch - 7ms/step
# Epoch 398/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 125ms/epoch - 7ms/step
# Epoch 399/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 123ms/epoch - 6ms/step
# Epoch 400/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 123ms/epoch - 6ms/step
# Epoch 401/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 120ms/epoch - 6ms/step
# Epoch 402/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 129ms/epoch - 7ms/step
# Epoch 403/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 138ms/epoch - 7ms/step
# Epoch 404/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 137ms/epoch - 7ms/step
# Epoch 405/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 134ms/epoch - 7ms/step
# Epoch 406/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 129ms/epoch - 7ms/step
# Epoch 407/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 122ms/epoch - 6ms/step
# Epoch 408/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 121ms/epoch - 6ms/step
# Epoch 409/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 131ms/epoch - 7ms/step
# Epoch 410/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 122ms/epoch - 6ms/step
# Epoch 411/1000
# 19/19 - 0s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - 122ms/epoch - 6ms/step
# Epoch 412/1000
# 19/19 - 0s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 126ms/epoch - 7ms/step
# Epoch 413/1000
# 19/19 - 0s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 124ms/epoch - 7ms/step
# Epoch 414/1000
# 19/19 - 0s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 122ms/epoch - 6ms/step
# Epoch 415/1000
# 19/19 - 0s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 122ms/epoch - 6ms/step
# Epoch 416/1000
# 19/19 - 0s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 122ms/epoch - 6ms/step
# Epoch 417/1000
# 19/19 - 0s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 123ms/epoch - 6ms/step
# Epoch 418/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 121ms/epoch - 6ms/step
# Epoch 419/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 121ms/epoch - 6ms/step
# Epoch 420/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 122ms/epoch - 6ms/step
# Epoch 421/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 422/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 122ms/epoch - 6ms/step
# Epoch 423/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 126ms/epoch - 7ms/step
# Epoch 424/1000
# 19/19 - 0s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 124ms/epoch - 7ms/step
# Epoch 425/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 126ms/epoch - 7ms/step
# Epoch 426/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 123ms/epoch - 6ms/step
# Epoch 427/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 121ms/epoch - 6ms/step
# Epoch 428/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 124ms/epoch - 7ms/step
# Epoch 429/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 122ms/epoch - 6ms/step
# Epoch 430/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 122ms/epoch - 6ms/step
# Epoch 431/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 123ms/epoch - 6ms/step
# Epoch 432/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - 122ms/epoch - 6ms/step
# Epoch 433/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 123ms/epoch - 6ms/step
# Epoch 434/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 120ms/epoch - 6ms/step
# Epoch 435/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 123ms/epoch - 6ms/step
# Epoch 436/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 134ms/epoch - 7ms/step
# Epoch 437/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 139ms/epoch - 7ms/step
# Epoch 438/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 125ms/epoch - 7ms/step
# Epoch 439/1000
# 19/19 - 0s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 136ms/epoch - 7ms/step
# Epoch 440/1000
# 19/19 - 0s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 120ms/epoch - 6ms/step
# Epoch 441/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 123ms/epoch - 6ms/step
# Epoch 442/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 120ms/epoch - 6ms/step
# Epoch 443/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 122ms/epoch - 6ms/step
# Epoch 444/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 136ms/epoch - 7ms/step
# Epoch 445/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 446/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 124ms/epoch - 7ms/step
# Epoch 447/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 121ms/epoch - 6ms/step
# Epoch 448/1000
# 19/19 - 0s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 120ms/epoch - 6ms/step
# Epoch 449/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 122ms/epoch - 6ms/step
# Epoch 450/1000
# 19/19 - 0s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 122ms/epoch - 6ms/step
# Epoch 451/1000
# 19/19 - 0s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 123ms/epoch - 6ms/step
# Epoch 452/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 122ms/epoch - 6ms/step
# Epoch 453/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 121ms/epoch - 6ms/step
# Epoch 454/1000
# 19/19 - 0s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 119ms/epoch - 6ms/step
# Epoch 455/1000
# 19/19 - 0s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 121ms/epoch - 6ms/step
# Epoch 456/1000
# 19/19 - 0s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 122ms/epoch - 6ms/step
# Epoch 457/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 151ms/epoch - 8ms/step
# Epoch 458/1000
# 19/19 - 0s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 124ms/epoch - 7ms/step
# Epoch 459/1000
# 19/19 - 0s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 127ms/epoch - 7ms/step
# Epoch 460/1000
# 19/19 - 0s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 122ms/epoch - 6ms/step
# Epoch 460: early stopping
# History
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %% [markdown]
# # Aufgabe 5
#
# Im untenstehenden Codeblock wird der Trainingsfortschritt geplottet. Wie beurteilen Sie ihn?

# %%
# Trainingsfortschritt plotten

plt.plot(history.history['mean_squared_error'], label='MSE (Trainingsdaten)')
plt.plot(history.history['val_mean_squared_error'], label='MSE (Testdaten)')

plt.title('Training: Entwicklung des Fehlers')
plt.ylabel('MSE-Fehler')
plt.xlabel('Epochen')
plt.legend()

# %%
# Testdaten in Merkmale X und Label y aufteilen

X_test = test_s.drop(columns = ['Verbrauch'])
y_test = pd.DataFrame(test_s['Verbrauch'])

# Vorhersage für skalierte Testdaten
X_test = np.array(X_test)
X_test_input = np.reshape(X_test, 
        (X_test.shape[0], X_test.shape[1], 1))

y_test = np.array(y_test)
#y_test = np.reshape(y_test, 
        # (y_test.shape[0],  1))
y_pred = model.predict(X_test_input)

pred = np.concatenate((X_test, y_pred), axis=1)

# Reskaliere die Daten
test_rs = pd.DataFrame(scaler.inverse_transform(test_s), columns = test_s.columns)
pred_rs = pd.DataFrame(scaler.inverse_transform(pred), columns = test_s.columns)

y_test = test_rs['Verbrauch']
y_pred = pred_rs['Verbrauch']

# Berechne RMSE der Validierungsdaten
mse = mean_squared_error(y_test, y_pred)
rmse = np.round(np.sqrt(mse))
print("Validierungs-Fehler:")
print("\nMSE:\n %.2lf" % (mse))
# Out:
# 5/5 [==============================] - 2s 2ms/step
# Validierungs-Fehler:
#
# MSE:
#  4818.78

# %%
def rel_error(df, col1, col2):
    df['Error (%)'] = (df[col1] - df[col2]) / df[col1]  * 100
    df['Error (%)'] = df['Error (%)'].abs()
    return df['Error (%)']

# %%
# Hilfsfunktion error_table erzeugt Fehlertabelle
def error_table(df1, df2, col1, col2, idx):
    cols = [df1, df2]
    headers = [col1, col2]
    # Erzeuge pred aus y_test und y_pred mit Index idx
    pred = pd.concat(cols, axis=1, keys=headers) 
    pred.set_index(idx, inplace=True)
    # Füge Fehler-Spalten hinzu
    pred['Error'] = np.abs(pred['y_test'] - pred['y_pred'])
    pred['Error(%)'] = rel_error(pred, 'y_test', 'y_pred')
    pred = pred.astype(float).round(1)
    # Füge RMSE hinzu
    mse = mean_squared_error(df1, df2)
    rmse = np.round(np.sqrt(mse))
    pred.index.name = "RMSE: " + str(rmse)
    return pred

# Erzeuge Fehlertabelle für Validierung und gebe sie aus
idx = test.index;
pred = error_table(pd.DataFrame(y_test), pd.DataFrame(y_pred), 'y_test', 'y_pred', idx)

pred.head()
# Out:
#               y_test    y_pred Error Error (%) Error(%)
#            Verbrauch Verbrauch
# RMSE: 69.0
# 2019-08-08    1326.6    1309.7  16.9       1.3      1.3
# 2019-08-09    1318.8    1304.7  14.1       1.1      1.1
# 2019-08-10    1132.4    1169.6  37.2       3.3      3.3
# 2019-08-11    1043.5    1067.1  23.6       2.3      2.3
# 2019-08-12    1299.0    1311.0  12.0       0.9      0.9

# %%
pred['Error (%)'].min()
# Out:
# 0.0

# %%
pred['Error (%)'].max()
# Out:
# 23.2
